# %% [markdown]
# # Brain MRI Stroke Classification
# ## Transfer Learning Visual Geometry Group (VGG) 16 layers model (Non-normalised images)

# %% [markdown]
# ## Set up

# %% [markdown]
# ### Modules

# %% [markdown]
# #### Published modules

# %%
# Data Manipulation
import numpy as np

# Machine Learning
## Training, validation and test sets
from sklearn.model_selection import train_test_split

# PyTorch
## Data loading
from torch.utils.data.dataloader import DataLoader
## Pre-processing
from torchvision import transforms
## Neural Network Architecture
import torch
import torch.nn as nn
## Transfer learning
from torchvision import models
from torchvision.models import VGG16_Weights
## Optimisiation
from torch.optim import Adam
## Misc
from torchsummary import summary
from torch_snippets import show, inspect

# Utilities
## os
import os
import sys
## Paths
from pyhere import here
from glob import glob
## Garbage colector
import gc

# %% [markdown]
# #### Project specific modules

# %%
path_to_project_modules = os.path.join(here('Src','Modules'))
sys.path.insert(0, path_to_project_modules)

from Project.datautils import StrokeImageData # Class inheriting from torch.utils.data.dataset.Dataset to load images
from Project.visualisation import display_image_samples
from Project.architecture import convolution_layer # A set of layers comprised of Conv2d, RelU activation, Batch Normalisation and Maxpool
from Project.modeltraining import train_model, evaluate_model

# %% [markdown]
# ### File paths

# %%
raw_data = os.path.join(here('Data', 'Raw')) #os.path.join transforms the output of pyhere.here from PosixPath to a text string
file_paths = glob(raw_data + '/*/*')

# %% [markdown]
# #### Random state

# %%
rand_state = 13 # For replication purposes
torch.manual_seed(rand_state)

# %% [markdown]
# #### PyTorch Backend

# %%
# Ensure the workflow is device agnostic 
device = 'cuda' if torch.cuda.is_available() else 'cpu'

print(f'Using {device} as Hardware Accelerator')
# Out:
# Using cuda as Hardware Accelerator

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Data loading and preparation

# %% [markdown]
# #### Data pre-processing

# %%
preproc_recipe = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    #transforms.Normalize(mean = [0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]) # Normalisation degrades too much black and white images, so a model without normalisation was trained
])

# %% [markdown]
# #### Train, validation and test sets

# %%
# Store classes in a list (for stratification)
y = [_file_path.split('/')[-2] for _file_path in file_paths]

# Generate Training and test sets
X_trainval, x_test, y_trainval, _ = train_test_split(file_paths, y, test_size=0.2, shuffle=True, stratify=y, random_state=rand_state)

# Further split training set into training and validation sets
X_train, X_val = train_test_split(X_trainval, test_size = 0.2, shuffle=True, stratify=y_trainval, random_state=rand_state)

# %% [markdown]
# #### Data loading

# %%
strk_train = StrokeImageData(X_train, device = device, recipe = preproc_recipe)
strk_val = StrokeImageData(X_val, device = device, recipe = preproc_recipe)
strk_test = StrokeImageData(x_test, device = device, recipe = preproc_recipe)

# %%
# Check Images are loaded correctly
display_image_samples(strk_train)

# %% [markdown]
# #### Data loaders

# %%
batch_size = 32

train_dl = DataLoader(strk_train, batch_size = batch_size, shuffle = True, drop_last = True) # Drop last batch as it only contains 6 images

val_dl = DataLoader(strk_val, batch_size = batch_size, shuffle = True, drop_last = True) # Drop last batch as it only contains 2 images

test_dl = DataLoader(strk_test, batch_size = batch_size, shuffle = True, drop_last = False)

# %% [markdown]
# ### Model specification

# %% [markdown]
# #### Network Architecture

# %%
m_vgg16 = models.vgg16(weights=VGG16_Weights.DEFAULT).to(device)

# Freeze model parameters
for param in m_vgg16.parameters():
    param.requires_grad = False

# Update the avgpool layer
m_vgg16.avgpool = nn.AdaptiveAvgPool2d(output_size=(1,1))

# Update classifier layer
m_vgg16.classifier = nn.Sequential(
    nn.Flatten(),
    nn.Linear(512, 128),
    nn.ReLU(),
    nn.Dropout(0.2),
    nn.Linear(128,1),
    nn.Sigmoid()
).to(device)

# %%
summary(m_vgg16, input_size=(3,224, 224), device=device)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 224, 224]           1,792
#               ReLU-2         [-1, 64, 224, 224]               0
#             Conv2d-3         [-1, 64, 224, 224]          36,928
#               ReLU-4         [-1, 64, 224, 224]               0
#          MaxPool2d-5         [-1, 64, 112, 112]               0
#             Conv2d-6        [-1, 128, 112, 112]          73,856
#               ReLU-7        [-1, 128, 112, 112]               0
#             Conv2d-8        [-1, 128, 112, 112]         147,584
#               ReLU-9        [-1, 128, 112, 112]               0
#         MaxPool2d-10          [-1, 128, 56, 56]               0
#            Conv2d-11          [-1, 256, 56, 56]         295,168
#              ReLU-12          [-1, 256, 56, 56]               0
#            Conv2d-13          [-1, 256, 56, 56]         590,080
#              ReLU-14          [-1, 256, 56, 56]               0
#            Conv2d-15          [-1, 256, 56, 56]         590,080
#              ReLU-16          [-1, 256, 56, 56]               0
#         MaxPool2d-17          [-1, 256, 28, 28]               0
#            Conv2d-18          [-1, 512, 28, 28]       1,180,160
#              ReLU-19          [-1, 512, 28, 28]               0
#            Conv2d-20          [-1, 512, 28, 28]       2,359,808
#              ReLU-21          [-1, 512, 28, 28]               0
#            Conv2d-22          [-1, 512, 28, 28]       2,359,808
#              ReLU-23          [-1, 512, 28, 28]               0
#         MaxPool2d-24          [-1, 512, 14, 14]               0
#            Conv2d-25          [-1, 512, 14, 14]       2,359,808
#              ReLU-26          [-1, 512, 14, 14]               0
#            Conv2d-27          [-1, 512, 14, 14]       2,359,808
#              ReLU-28          [-1, 512, 14, 14]               0
#            Conv2d-29          [-1, 512, 14, 14]       2,359,808
#              ReLU-30          [-1, 512, 14, 14]               0
#         MaxPool2d-31            [-1, 512, 7, 7]               0
# AdaptiveAvgPool2d-32            [-1, 512, 1, 1]               0
#           Flatten-33                  [-1, 512]               0
#            Linear-34                  [-1, 128]          65,664
#              ReLU-35                  [-1, 128]               0
#           Dropout-36                  [-1, 128]               0
#            Linear-37                    [-1, 1]             129
#           Sigmoid-38                    [-1, 1]               0
# ================================================================
# Total params: 14,780,481
# Trainable params: 65,793
# Non-trainable params: 14,714,688
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 218.41
# Params size (MB): 56.38
# Estimated Total Size (MB): 275.36
# ----------------------------------------------------------------

# %% [markdown]
# ### Hyperparameters

# %% [markdown]
# #### Epochs

# %%
n_epochs = 500

# %% [markdown]
# #### Optimiser

# %%
optim = Adam
lr = 1e-3

# learning rate annealing
scheduler_kws = {
    'factor':0.5, 
    'patience':0, 
    'threshold':1e-3, 
    'verbose':True, 
    'min_lr':1e-6, 
    'threshold_mode':'abs'}

# Early stop
earlystop_kws = {
    'patience': 5,
    'min_delta': 1e-3
}

# %% [markdown]
# #### Loss Function

# %%
loss_fn = nn.BCELoss() # Binary Cross Entropy

# %% [markdown]
# #### Model training

# %%
train_model(train_dl, val_dl, m_vgg16, loss_fn, optim, lr, n_epochs, kws_lr_scheduler = scheduler_kws, kws_early_stop = earlystop_kws)
# Out:
# Learning rate annealing enabled...
# Early stop enabled...
# Epoch: 1;
# Training accuracy: 66.17%, Training loss: 0.64069 ---------- Validation accuracy: 68.75%, Validation loss: 0.60254
# Epoch: 2;
# Training accuracy: 71.33%, Training loss: 0.56506 ---------- Validation accuracy: 76.25%, Validation loss: 0.54314
# Epoch: 3;
# Training accuracy: 72.34%, Training loss: 0.52859 ---------- Validation accuracy: 76.25%, Validation loss: 0.51116
# Epoch: 4;
# Training accuracy: 77.50%, Training loss: 0.48833 ---------- Validation accuracy: 78.12%, Validation loss: 0.48919
# Epoch: 5;
# Training accuracy: 78.12%, Training loss: 0.46822 ---------- Validation accuracy: 76.56%, Validation loss: 0.47677
# Epoch: 6;
# Training accuracy: 79.77%, Training loss: 0.44015 ---------- Validation accuracy: 79.38%, Validation loss: 0.45488
# Epoch: 7;
# Training accuracy: 81.17%, Training loss: 0.42608 ---------- Validation accuracy: 76.56%, Validation loss: 0.46914
# Epoch 00007: reducing learning rate of group 0 to 5.0000e-04.
# Epoch: 8;
# Training accuracy: 80.86%, Training loss: 0.41113 ---------- Validation accuracy: 82.50%, Validation loss: 0.42582
# Epoch: 9;
# Training accuracy: 82.27%, Training loss: 0.40165 ---------- Validation accuracy: 83.12%, Validation loss: 0.42148
# Epoch: 10;
# Training accuracy: 83.67%, Training loss: 0.38898 ---------- Validation accuracy: 83.44%, Validation loss: 0.41497
# Epoch: 11;
# Training accuracy: 82.97%, Training loss: 0.38421 ---------- Validation accuracy: 84.06%, Validation loss: 0.41272
# Epoch: 12;
# Training accuracy: 84.69%, Training loss: 0.37564 ---------- Validation accuracy: 83.44%, Validation loss: 0.40596
# Epoch: 13;
# Training accuracy: 84.06%, Training loss: 0.36977 ---------- Validation accuracy: 83.44%, Validation loss: 0.40448
# Epoch: 14;
# Training accuracy: 84.45%, Training loss: 0.37221 ---------- Validation accuracy: 84.06%, Validation loss: 0.39747
# Epoch: 15;
# Training accuracy: 85.23%, Training loss: 0.35999 ---------- Validation accuracy: 82.50%, Validation loss: 0.39657
# Epoch 00015: reducing learning rate of group 0 to 2.5000e-04.
# Epoch: 16;
# Training accuracy: 85.39%, Training loss: 0.35905 ---------- Validation accuracy: 84.69%, Validation loss: 0.39667
# Epoch 00016: reducing learning rate of group 0 to 1.2500e-04.
# Epoch: 17;
# Training accuracy: 85.62%, Training loss: 0.35154 ---------- Validation accuracy: 84.38%, Validation loss: 0.39981
# Epoch 00017: reducing learning rate of group 0 to 6.2500e-05.
# Epoch: 18;
# Training accuracy: 86.09%, Training loss: 0.35337 ---------- Validation accuracy: 84.69%, Validation loss: 0.39581
# Epoch: 19;
# Training accuracy: 85.62%, Training loss: 0.35298 ---------- Validation accuracy: 85.00%, Validation loss: 0.39274
# Epoch: 20;
# Training accuracy: 85.39%, Training loss: 0.34936 ---------- Validation accuracy: 84.69%, Validation loss: 0.39607
# Epoch 00020: reducing learning rate of group 0 to 3.1250e-05.
# Epoch: 21;
# Training accuracy: 86.09%, Training loss: 0.34505 ---------- Validation accuracy: 84.69%, Validation loss: 0.39584
# Epoch 00021: reducing learning rate of group 0 to 1.5625e-05.
# Epoch: 22;
# Training accuracy: 85.70%, Training loss: 0.34305 ---------- Validation accuracy: 84.69%, Validation loss: 0.39523
# Epoch 00022: reducing learning rate of group 0 to 7.8125e-06.
# Epoch: 23;
# Training accuracy: 85.94%, Training loss: 0.34439 ---------- Validation accuracy: 85.00%, Validation loss: 0.39405
# Epoch 00023: reducing learning rate of group 0 to 3.9063e-06.
# Epoch: 24;
# Training accuracy: 85.23%, Training loss: 0.34954 ---------- Validation accuracy: 84.69%, Validation loss: 0.39457
# Epoch 00024: reducing learning rate of group 0 to 1.9531e-06.
# Early stop at epoch: 24 of 500

# %% [markdown]
# ## Performance in the Test set

# %%
test_acc, test_loss = evaluate_model(test_dl, m_vgg16, loss_fn, 0.5)
print(f"Test data:\n  Accuracy: {test_acc*100:.2f}%\n  Loss:    {test_loss:.5f}")
# Out:
# Test data:
#   Accuracy: 79.60%
#   Loss:    0.43736
