# %% [markdown]
# # Brain MRI Stroke Classification (Convolutional Neural Network from Scratch)

# %% [markdown]
# ## Set up

# %% [markdown]
# ### Modules

# %% [markdown]
# #### Published modules

# %%
# Data Manipulation
import numpy as np

# Machine Learning
## Training, validation and test sets
from sklearn.model_selection import train_test_split

# PyTorch
## Data loading
from torch.utils.data.dataloader import DataLoader
## Pre-processing
from torchvision import transforms
## Neural Network Architecture
import torch
import torch.nn as nn
## Optimisiation
from torch.optim import Adam
## Misc
from torchsummary import summary
from torch_snippets import show, inspect

# Utilities
## os
import os
import sys
## Paths
from pyhere import here
from glob import glob
## Garbage colector
import gc

# %% [markdown]
# #### Project specific modules

# %%
path_to_project_modules = os.path.join(here('Src','Modules'))
sys.path.insert(0, path_to_project_modules)

from Project.datautils import StrokeImageData # Class inheriting from torch.utils.data.dataset.Dataset to load images
from Project.visualisation import display_image_samples
from Project.architecture import convolution_layer # A set of layers comprised of Conv2d, RelU activation, Batch Normalisation and Maxpool
from Project.modeltraining import train_model, evaluate_model

# %% [markdown]
# ### File paths

# %%
raw_data = os.path.join(here('Data', 'Raw')) #os.path.join transforms the output of pyhere.here from PosixPath to a text string
file_paths = glob(raw_data + '/*/*')

# %% [markdown]
# #### Random state

# %%
rand_state = 13 # For replication purposes
torch.manual_seed(rand_state)

# %% [markdown]
# #### PyTorch Backend

# %%
# Ensure the workflow is device agnostic 
device = 'cuda' if torch.cuda.is_available() else 'cpu'

print(f'Using {device} as Hardware Accelerator')
# Out:
# Using cuda as Hardware Accelerator

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Data loading and preparation

# %% [markdown]
# #### Data pre-processing

# %%
preproc_recipe = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor() # also performs normalises the data to values between 0 and 1
])

# %% [markdown]
# #### Train, validation and test sets

# %%
# Store classes in a list (for stratification)
y = [_file_path.split('/')[-2] for _file_path in file_paths]

# Generate Training and test sets
X_trainval, x_test, y_trainval, _ = train_test_split(file_paths, y, test_size=0.2, shuffle=True, stratify=y, random_state=rand_state)

# Further split training set into training and validation sets
X_train, X_val = train_test_split(X_trainval, test_size = 0.2, shuffle=True, stratify=y_trainval, random_state=rand_state)

# %% [markdown]
# #### Data loading

# %%
strk_train = StrokeImageData(X_train, device = device, recipe = preproc_recipe)
strk_val = StrokeImageData(X_val, device = device, recipe = preproc_recipe)
strk_test = StrokeImageData(x_test, device = device, recipe = preproc_recipe)

# %%
# Check Images are loaded correctly
display_image_samples(strk_train)

# %% [markdown]
# #### Data loaders

# %%
batch_size = 32

train_dl = DataLoader(strk_train, batch_size = batch_size, shuffle = True, drop_last = True) # Drop last batch as it only contains 6 images

val_dl = DataLoader(strk_val, batch_size = batch_size, shuffle = True, drop_last = True) # Drop last batch as it only contains 2 images

test_dl = DataLoader(strk_test, batch_size = batch_size, shuffle = True, drop_last = False)

# %% [markdown]
# ### Model specification

# %% [markdown]
# #### Network Architecture

# %%
m_one = nn.Sequential(
    convolution_layer(3, 64, 3),
    convolution_layer(64, 128, 3),
    convolution_layer(128, 256, 3),
    convolution_layer(256, 512, 3),
    convolution_layer(512, 512, 3),
    convolution_layer(512, 128, 3),
    nn.Flatten(),
    nn.Linear(128,64),
    nn.ReLU(),
    nn.Dropout(0.2),
    nn.Linear(64,1),
    nn.Sigmoid()
).to(device)

# %%
summary(m_one, input_size=(3,224, 224), device=device)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 222, 222]           1,792
#               ReLU-2         [-1, 64, 222, 222]               0
#        BatchNorm2d-3         [-1, 64, 222, 222]             128
#          MaxPool2d-4         [-1, 64, 111, 111]               0
#             Conv2d-5        [-1, 128, 109, 109]          73,856
#               ReLU-6        [-1, 128, 109, 109]               0
#        BatchNorm2d-7        [-1, 128, 109, 109]             256
#          MaxPool2d-8          [-1, 128, 54, 54]               0
#             Conv2d-9          [-1, 256, 52, 52]         295,168
#              ReLU-10          [-1, 256, 52, 52]               0
#       BatchNorm2d-11          [-1, 256, 52, 52]             512
#         MaxPool2d-12          [-1, 256, 26, 26]               0
#            Conv2d-13          [-1, 512, 24, 24]       1,180,160
#              ReLU-14          [-1, 512, 24, 24]               0
#       BatchNorm2d-15          [-1, 512, 24, 24]           1,024
#         MaxPool2d-16          [-1, 512, 12, 12]               0
#            Conv2d-17          [-1, 512, 10, 10]       2,359,808
#              ReLU-18          [-1, 512, 10, 10]               0
#       BatchNorm2d-19          [-1, 512, 10, 10]           1,024
#         MaxPool2d-20            [-1, 512, 5, 5]               0
#            Conv2d-21            [-1, 128, 3, 3]         589,952
#              ReLU-22            [-1, 128, 3, 3]               0
#       BatchNorm2d-23            [-1, 128, 3, 3]             256
#         MaxPool2d-24            [-1, 128, 1, 1]               0
#           Flatten-25                  [-1, 128]               0
#            Linear-26                   [-1, 64]           8,256
#              ReLU-27                   [-1, 64]               0
#           Dropout-28                   [-1, 64]               0
#            Linear-29                    [-1, 1]              65
#           Sigmoid-30                    [-1, 1]               0
# ================================================================
# Total params: 4,512,257
# Trainable params: 4,512,257
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 141.64
# Params size (MB): 17.21
# Estimated Total Size (MB): 159.43
# ----------------------------------------------------------------

# %% [markdown]
# ### Hyperparameters

# %% [markdown]
# #### Epochs

# %%
n_epochs = 500

# %% [markdown]
# #### Optimiser

# %%
optim = Adam
lr = 1e-4

# learning rate annealing
scheduler_kws = {
    'factor':0.5, 
    'patience':0, 
    'threshold':1e-3, 
    'verbose':True, 
    'min_lr':1e-5, 
    'threshold_mode':'abs'}

# Early stop
earlystop_kws = {
    'patience': 5,
    'min_delta': 1e-3
}

# %% [markdown]
# #### Loss Function

# %%
loss_fn = nn.BCELoss() # Binary Cross Entropy

# %% [markdown]
# #### Model training

# %%
train_model(train_dl, val_dl, m_one, loss_fn, optim, lr, n_epochs, kws_lr_scheduler = scheduler_kws, kws_early_stop = earlystop_kws)
# Out:
# Learning rate annealing enabled...
# Early stop enabled...
# Epoch: 1;
# Training accuracy: 71.48%, Training loss: 0.54985 ---------- Validation accuracy: 50.62%, Validation loss: 0.74748
# Epoch: 2;
# Training accuracy: 83.91%, Training loss: 0.39833 ---------- Validation accuracy: 82.50%, Validation loss: 0.42495
# Epoch: 3;
# Training accuracy: 89.30%, Training loss: 0.29460 ---------- Validation accuracy: 83.44%, Validation loss: 0.36704
# Epoch: 4;
# Training accuracy: 91.41%, Training loss: 0.25233 ---------- Validation accuracy: 78.75%, Validation loss: 0.47435
# Epoch 00004: reducing learning rate of group 0 to 5.0000e-05.
# Epoch: 5;
# Training accuracy: 95.39%, Training loss: 0.16623 ---------- Validation accuracy: 90.94%, Validation loss: 0.24351
# Epoch: 6;
# Training accuracy: 98.52%, Training loss: 0.08724 ---------- Validation accuracy: 90.94%, Validation loss: 0.24594
# Epoch 00006: reducing learning rate of group 0 to 2.5000e-05.
# Epoch: 7;
# Training accuracy: 99.30%, Training loss: 0.05624 ---------- Validation accuracy: 92.50%, Validation loss: 0.19854
# Epoch: 8;
# Training accuracy: 99.77%, Training loss: 0.04254 ---------- Validation accuracy: 94.38%, Validation loss: 0.16974
# Epoch: 9;
# Training accuracy: 99.77%, Training loss: 0.03168 ---------- Validation accuracy: 95.31%, Validation loss: 0.15816
# Epoch: 10;
# Training accuracy: 100.00%, Training loss: 0.02439 ---------- Validation accuracy: 94.06%, Validation loss: 0.16626
# Epoch 00010: reducing learning rate of group 0 to 1.2500e-05.
# Epoch: 11;
# Training accuracy: 99.92%, Training loss: 0.02226 ---------- Validation accuracy: 94.06%, Validation loss: 0.16173
# Epoch 00011: reducing learning rate of group 0 to 1.0000e-05.
# Epoch: 12;
# Training accuracy: 100.00%, Training loss: 0.01933 ---------- Validation accuracy: 94.69%, Validation loss: 0.15461
# Epoch: 13;
# Training accuracy: 100.00%, Training loss: 0.01819 ---------- Validation accuracy: 94.38%, Validation loss: 0.15350
# Epoch: 14;
# Training accuracy: 100.00%, Training loss: 0.01588 ---------- Validation accuracy: 93.75%, Validation loss: 0.15693
# Epoch: 15;
# Training accuracy: 100.00%, Training loss: 0.01379 ---------- Validation accuracy: 95.31%, Validation loss: 0.14924
# Epoch: 16;
# Training accuracy: 100.00%, Training loss: 0.01377 ---------- Validation accuracy: 95.00%, Validation loss: 0.15006
# Epoch: 17;
# Training accuracy: 100.00%, Training loss: 0.01247 ---------- Validation accuracy: 95.00%, Validation loss: 0.15248
# Epoch: 18;
# Training accuracy: 100.00%, Training loss: 0.01202 ---------- Validation accuracy: 95.00%, Validation loss: 0.15006
# Epoch: 19;
# Training accuracy: 100.00%, Training loss: 0.01138 ---------- Validation accuracy: 95.31%, Validation loss: 0.14615
# Epoch: 20;
# Training accuracy: 100.00%, Training loss: 0.01049 ---------- Validation accuracy: 94.06%, Validation loss: 0.15723
# Epoch: 21;
# Training accuracy: 100.00%, Training loss: 0.01032 ---------- Validation accuracy: 94.06%, Validation loss: 0.15728
# Epoch: 22;
# Training accuracy: 100.00%, Training loss: 0.00909 ---------- Validation accuracy: 95.00%, Validation loss: 0.14492
# Epoch: 23;
# Training accuracy: 100.00%, Training loss: 0.00833 ---------- Validation accuracy: 94.69%, Validation loss: 0.14718
# Epoch: 24;
# Training accuracy: 100.00%, Training loss: 0.00856 ---------- Validation accuracy: 95.00%, Validation loss: 0.14643
# Epoch: 25;
# Training accuracy: 100.00%, Training loss: 0.00829 ---------- Validation accuracy: 95.31%, Validation loss: 0.14523
# Epoch: 26;
# Training accuracy: 100.00%, Training loss: 0.00794 ---------- Validation accuracy: 94.38%, Validation loss: 0.15785
# Epoch: 27;
# Training accuracy: 100.00%, Training loss: 0.00755 ---------- Validation accuracy: 95.00%, Validation loss: 0.15334
# Epoch: 28;
# Training accuracy: 100.00%, Training loss: 0.00701 ---------- Validation accuracy: 95.00%, Validation loss: 0.14533
# Epoch: 29;
# Training accuracy: 100.00%, Training loss: 0.00657 ---------- Validation accuracy: 94.69%, Validation loss: 0.14871
# Early stop at epoch: 29 of 50

# %% [markdown]
# ## Performance in the Test set

# %%
test_acc, test_loss = evaluate_model(test_dl, m_one, loss_fn, 0.5)
print(f"Test data:\n  Accuracy: {test_acc*100:.2f}%\n  Loss:    {test_loss:.5f}")
# Out:
# Test data:
#   Accuracy: 91.29%
#   Loss:    0.20712
